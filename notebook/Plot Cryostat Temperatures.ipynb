# %%
import seaborn as sns
from runco import config, sc
import datetime
import matplotlib.pyplot as plt
import numpy

sns.set_context('notebook')
sns.set_style('whitegrid')
# %matplotlib notebook

# %%
conf = config.Config()

# %%
slowcon = sc.ConfiguredSlowControls(conf.data['slowcontrols'])
ch = slowcon.channel_id_by_name['uB_Cryo_IFIX_1_0/TE183']

# %%
now = datetime.datetime.now()
one_week_ago = now - datetime.timedelta(hours=12)

# %%
form = lambda x : x.strftime("%Y-%m-%d %H:%M:%S")

# %%
slowcon.query_timebinned_data(ch,1, form(one_week_ago), form(now))
result = slowcon.cur.fetchall()

# %%
x = [datetime.datetime.fromtimestamp(i[1]) for i in result]
y = [i[2] for i in result]

# %%
ax = plt.figure()
plt.plot(x,y)
plt.xlabel('Date/Time')
plt.ylabel('Level (m)')
ax.autofmt_xdate()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
one_week_ago = now - datetime.timedelta(hours=3)
slowcon.query_timebinned_data(ch,1, form(one_week_ago), form(now))
result = slowcon.cur.fetchall()
x = [datetime.datetime.fromtimestamp(i[1]) for i in result]
y = [i[2] for i in result]
ax = plt.figure()
plt.plot(x,y)
plt.xlabel('Date/Time')
plt.ylabel('Level (m)')
ax.autofmt_xdate()
# Out:
# <img src="data:image/png;base64,..." width="640">
